# %%
! python3 ubuntu_evaluation.py
# Out:
# ...
# COMPREHENSIVE LLM EVALUATION - UBUNTU RTX 5090
# LLAMA 70B (Groq) vs Qwen2.5-7B V2 (Fine-tuned)
# ...
#
# [1/6] Loading test cases...
#   Loaded 22 test cases
#
# [2/6] Loading LLM models...
#   Loading LLAMA 70B (Groq API)... OK
#   Loading Qwen V2 (local base + LoRA merge)... [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|████████████████████████| 339/339 [00:11<00:00, 30.52it/s]
# OK (merged, on cuda:0)
# Loading weights: 100%|██████████████████████| 105/105 [00:00<00:00, 3201.48it/s]
# OK
#   Loading Qdrant local storage... OK
#
# [3/6] Running evaluation on all test cases...
#   [1/22] shunt type 1+2 - large diameter (c) (l) OK
#   [2/22] shunt type 1+2 - small diameter (c) (l) OK
#   [3/22] shunt type 1 (c) (l) OK
#   [4/22] shunt type 2 - equal calibre, equal distance (c) (l) OK
#   [5/22] shunt type 2 - equal calibre, unequal distance (c) (l) OK
#   [6/22] shunt type 2 - unequal calibre, no drainage (c) (l) OK
# ...

# %%
! python3 ubuntu_evaluation.py
# Out:
# ...
# COMPREHENSIVE LLM EVALUATION - UBUNTU RTX 5090
# LLAMA 70B (Groq) vs Qwen2.5-7B V2 (Fine-tuned)
# ...
#
# [1/6] Loading test cases...
#   Loaded 22 test cases
#
# [2/6] Loading LLM models...
#   Loading LLAMA 70B (Groq API)... OK
#   Loading Qwen V2 (local base + LoRA merge)... [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|████████████████████████| 339/339 [00:08<00:00, 40.79it/s]
# OK (merged, on cuda:0)
# Loading weights: 100%|██████████████████████| 105/105 [00:00<00:00, 4799.71it/s]
# OK
#   Loading Qdrant local storage... OK
#
# [3/6] Running evaluation on all test cases...
#   [1/22] shunt type 1+2 - large diameter (c) (l) OK
#   [2/22] shunt type 1+2 - small diameter (c) (l) OK
#   [3/22] shunt type 1 (c) (l) OK
#   [4/22] shunt type 2 - equal calibre, equal distance (c) (l) OK
#   [5/22] shunt type 2 - equal calibre, unequal distance (c) (l) OK
#   [6/22] shunt type 2 - unequal calibre, no drainage (c) (l) OK
# ...

# %%
! python3 ubuntu_evaluation.py
# Out:
# ...
# COMPREHENSIVE LLM EVALUATION - UBUNTU RTX 5090
# LLAMA 70B (Groq) vs Qwen2.5-7B V2 (Fine-tuned)
# ...
#
# [1/6] Loading test cases...
#   Loaded 22 test cases
#
# [2/6] Loading LLM models...
#   Loading LLAMA 70B (Groq API)... OK
#   Loading Qwen V2 (local base + LoRA merge)... [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|████████████████████████| 339/339 [00:08<00:00, 40.87it/s]
# OK (merged, on cuda:0)
# Loading weights: 100%|██████████████████████| 105/105 [00:00<00:00, 3847.48it/s]
# OK
#   Loading Qdrant local storage... OK
#
# [3/6] Running evaluation on all test cases...
#   [1/22] shunt type 1+2 - large diameter (c) [transformers] The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# (l) OK
#   [2/22] shunt type 1+2 - small diameter (c) (l) OK
#   [3/22] shunt type 1 (c) (l) OK
#   [4/22] shunt type 2 - equal calibre, equal distance (c) (l) OK
# ...
