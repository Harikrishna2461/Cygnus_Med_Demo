# %%
# ! echo 'export LD_LIBRARY_PATH=/usr/lib/wsl/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/cuda_runtime/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/cublas/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/cufft/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/curand/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/cusolver/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/cusparse/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/cudnn/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/nvjitlink/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/nccl/lib:$LD_LIBRARY_PATH' >> ~/.bashrc && source ~/.bashrc

# %%
# echo 'export LD_LIBRARY_PATH=/usr/lib/wsl/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/cuda_runtime/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/cublas/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/cufft/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/curand/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/cusolver/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/cusparse/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/cudnn/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/nvjitlink/lib:/home/krish/miniconda/lib/python3.13/site-packages/nvidia/nccl/lib:$LD_LIBRARY_PATH' >> ~/.bashrc && source ~/.bashrc

# %% [markdown]
# **Run the above in ubuntu terminal before running the following cells**

# %%
import tensorflow as tf
import numpy as np, pandas as pd, cv2, time
from pathlib import Path
import os
import matplotlib.pyplot as plt

os.environ['TF_CUDNN_USE_AUTOTUNE']       = '0'
os.environ['TF_XLA_FLAGS']               = '--tf_xla_auto_jit=0'
os.environ['TF_DISABLE_MKL']             = '1'
os.environ['CUDA_DEVICE_MAX_CONNECTIONS']= '1'
tf.config.optimizer.set_jit(False)

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    tf.config.experimental.set_memory_growth(gpus[0], True)
    print(f'GPU: {gpus[0].name}')
else:
    print('WARNING: No GPU found')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779943414.119954    4018 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1779943414.155404    4018 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI AVX_VNNI_INT8 AVX_NE_CONVERT FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779943415.294320    4018 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# GPU: /physical_device:GPU:0
# W0000 00:00:1779943416.739937    4018 gpu_device.cc:2459] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0a. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.

# %%
import tensorflow as tf
import numpy as np, pandas as pd, cv2, time
from pathlib import Path
import os
import matplotlib.pyplot as plt

os.environ['TF_CUDNN_USE_AUTOTUNE']       = '0'
os.environ['TF_XLA_FLAGS']                = '--tf_xla_auto_jit=0'
os.environ['TF_DISABLE_MKL']              = '1'
os.environ['CUDA_DEVICE_MAX_CONNECTIONS'] = '1'
tf.config.optimizer.set_jit(False)

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    tf.config.experimental.set_memory_growth(gpus[0], True)
    print(f'GPU: {gpus[0].name}')
else:
    print('WARNING: No GPU found — running on CPU')
# Out:
# GPU: /physical_device:GPU:0

# %%
DATA_ROOT = Path('/home/krish/vein_detection_task_3_training')
VEIN_DIR  = DATA_ROOT / 'output/vein'
CKPT_DIR  = VEIN_DIR / 'checkpoints'
PLOT_DIR  = VEIN_DIR / 'plots'
CKPT_DIR.mkdir(parents=True, exist_ok=True)
PLOT_DIR.mkdir(parents=True, exist_ok=True)

IMG_SIZE   = 256
BATCH_SIZE = 8
EPOCHS     = 60
LR         = 1e-4
N_CLASSES  = 2
VAL_FRAC   = 0.15
SEED       = 42

print('Config OK')
print(f'  IMG_SIZE={IMG_SIZE}, BATCH={BATCH_SIZE}, EPOCHS={EPOCHS}, LR={LR}')
# Out:
# Config OK
#   IMG_SIZE=256, BATCH=8, EPOCHS=60, LR=0.0001

# %%
df_all  = pd.read_csv(VEIN_DIR / 'metadata.csv')
df_vein = df_all[df_all['has_vein']].reset_index(drop=True)
print(f'Total frames : {len(df_all)}')
print(f'With veins   : {len(df_vein)}')

df_vein['frame_path'] = df_vein['frame_path'].apply(
    lambda p: str(DATA_ROOT / p) if not p.startswith('/') else p)
df_vein['mask_path'] = df_vein['mask_path'].apply(
    lambda p: str(DATA_ROOT / p) if not p.startswith('/') else p)

print('Validating files...')
valid = []
for _, row in df_vein.iterrows():
    f = cv2.imread(row['frame_path'])
    m = cv2.imread(row['mask_path'], cv2.IMREAD_GRAYSCALE)
    if f is not None and m is not None and f.shape[:2] == m.shape[:2]:
        valid.append(row)
df_clean = pd.DataFrame(valid).reset_index(drop=True)
print(f'Valid pairs  : {len(df_clean)} / {len(df_vein)}')
# Out:
# Total frames : 2295
# With veins   : 2037
# Validating files...
# libpng error: Read Error
# Valid pairs  : 2036 / 2037

# %%
from sklearn.model_selection import train_test_split

train_df, val_df = train_test_split(
    df_clean, test_size=VAL_FRAC, random_state=SEED, shuffle=True)
train_df = train_df.reset_index(drop=True)
val_df   = val_df.reset_index(drop=True)

print(f'Train: {len(train_df)}  |  Val: {len(val_df)}')
# Out:
# Train: 1730  |  Val: 306

# %%
MEAN_NP = np.array([0.485, 0.456, 0.406], np.float32)
STD_NP  = np.array([0.229, 0.224, 0.225], np.float32)

def _load_pair(fp, mp):
    img  = cv2.cvtColor(cv2.imread(fp.decode()), cv2.COLOR_BGR2RGB)
    mask = cv2.imread(mp.decode(), cv2.IMREAD_GRAYSCALE)
    img  = cv2.resize(img,  (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_LINEAR)
    mask = cv2.resize(mask, (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_NEAREST)
    img  = img.astype(np.float32) / 255.
    mask = (mask > 0).astype(np.int32)
    return img, mask

def make_dataset(dataframe, batch_size, shuffle=False):
    fps = dataframe['frame_path'].values
    mps = dataframe['mask_path'].values
    def load(fp, mp):
        img, mask = tf.numpy_function(_load_pair, [fp, mp], [tf.float32, tf.int32])
        img  = (img - MEAN_NP) / STD_NP
        img.set_shape([IMG_SIZE, IMG_SIZE, 3])
        mask.set_shape([IMG_SIZE, IMG_SIZE])
        return img, mask
    ds = tf.data.Dataset.from_tensor_slices((fps, mps))
    if shuffle:
        ds = ds.shuffle(len(dataframe), seed=SEED)
    ds = ds.map(load, num_parallel_calls=tf.data.AUTOTUNE)
    return ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

train_ds = make_dataset(train_df, BATCH_SIZE, shuffle=True)
val_ds   = make_dataset(val_df,   BATCH_SIZE, shuffle=False)

for xb, yb in train_ds.take(1):
    print(f'Image batch : {xb.shape} {xb.dtype}')
    print(f'Mask  batch : {yb.shape} {yb.dtype}  unique={np.unique(yb.numpy())}')
    vein_pct = float(tf.reduce_mean(tf.cast(yb == 1, tf.float32))) * 100
    print(f'Vein pixel %: {vein_pct:.2f}%')
# Out:
# W0000 00:00:1779943423.069976    4018 gpu_device.cc:2459] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0a. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# I0000 00:00:1779943423.152139    4018 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 29043 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 5090, pci bus id: 0000:02:00.0, compute capability: 12.0a
# E0000 00:00:1779943423.246212    4148 ptx_compiler_helpers.cc:154] *** WARNING *** Invoking ptxas with version 12.0.140, which corresponds to a CUDA version <=12.6.2. CUDA versions 12.x.y up to and including 12.6.2 miscompile certain edge cases around clamping.
# Please upgrade to CUDA 12.6.3 or newer.
# W0000 00:00:1779943423.248416    4148 subprocess_compilation.cc:241] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 12.0
# W0000 00:00:1779943423.248438    4148 subprocess_compilation.cc:244] Used ptxas at /usr/bin/ptxas
# W0000 00:00:1779943423.248475    4148 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943423.249173    4147 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943423.250557    4146 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943423.251760    4149 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943423.253178    4144 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943423.254259    4151 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943423.255305    4143 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943423.256703    4150 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943423.491066    4172 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943423.492442    4168 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943423.493804    4165 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943423.494930    4167 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943423.496401    4169 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943423.497916    4170 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943423.498975    4164 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943423.500427    4171 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943423.501230    4166 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# Image batch : (8, 256, 256, 3) <dtype: 'float32'>
# Mask  batch : (8, 256, 256) <dtype: 'int32'>  unique=[0 1]
# Vein pixel %: 1.75%

# %%
n = 8
sample = train_df.sample(n, random_state=SEED).reset_index(drop=True)

fig, axes = plt.subplots(n, 3, figsize=(12, n * 3))
for i, row in sample.iterrows():
    raw  = cv2.cvtColor(cv2.imread(row['frame_path']), cv2.COLOR_BGR2RGB)
    raw  = cv2.resize(raw, (IMG_SIZE, IMG_SIZE))
    mask = cv2.imread(row['mask_path'], cv2.IMREAD_GRAYSCALE)
    mask = cv2.resize(mask, (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_NEAREST)
    mask = (mask > 0).astype(np.uint8)

    overlay = raw.copy()
    overlay[mask == 1] = (overlay[mask == 1] * 0.4 + np.array([0, 255, 0]) * 0.6).astype(np.uint8)

    axes[i, 0].imshow(raw);          axes[i, 0].set_title('Frame')
    axes[i, 1].imshow(mask, cmap='gray'); axes[i, 1].set_title('Vein Mask')
    axes[i, 2].imshow(overlay);      axes[i, 2].set_title('Overlay')
    for ax in axes[i]:
        ax.axis('off')

plt.suptitle('Dataset Samples — Green = Vein Annotation', fontsize=13, y=1.001)
plt.tight_layout()
plt.show()
print(f'Vein pixel coverage: {mask.mean()*100:.2f}% (last sample)')
# Out:
# Vein pixel coverage: 2.16% (last sample)

# %%
CW_VEIN = tf.constant([0.5, 15.0], dtype=tf.float32)

def vein_dice_ce_loss(y_true, y_pred):
    smooth   = 1e-6
    y_true_i = tf.cast(y_true, tf.int32)
    y_oh     = tf.one_hot(y_true_i, N_CLASSES)
    inter    = tf.reduce_sum(y_pred * y_oh, axis=[0, 1, 2])
    union    = tf.reduce_sum(y_pred + y_oh, axis=[0, 1, 2])
    dice     = 1. - tf.reduce_mean((2. * inter + smooth) / (union + smooth))
    ce       = tf.keras.losses.sparse_categorical_crossentropy(y_true, y_pred)
    ce       = tf.reduce_mean(ce * tf.gather(CW_VEIN, y_true_i))
    return 0.5 * dice + 0.5 * ce

def vein_iou(y_true, y_pred):
    pc = tf.cast(tf.argmax(y_pred, -1), tf.int32)
    tc = tf.cast(y_true, tf.int32)
    tp = tf.reduce_sum(tf.cast(tf.equal(pc, 1) & tf.equal(tc, 1),     tf.float32))
    fp = tf.reduce_sum(tf.cast(tf.equal(pc, 1) & tf.not_equal(tc, 1), tf.float32))
    fn = tf.reduce_sum(tf.cast(tf.not_equal(pc, 1) & tf.equal(tc, 1), tf.float32))
    return tp / (tp + fp + fn + 1e-6)

def vein_dice(y_true, y_pred):
    pc = tf.cast(tf.argmax(y_pred, -1) == 1, tf.float32)
    tc = tf.cast(tf.cast(y_true, tf.int32) == 1, tf.float32)
    return 2. * tf.reduce_sum(pc * tc) / (tf.reduce_sum(pc) + tf.reduce_sum(tc) + 1e-6)

def conv_block(x, f):
    for _ in range(2):
        x = tf.keras.layers.Conv2D(f, 3, padding='same', use_bias=False)(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.ReLU()(x)
    return x

def build_unet(n_classes=N_CLASSES):
    inp  = tf.keras.Input((IMG_SIZE, IMG_SIZE, 3))
    base = tf.keras.applications.ResNet50(
        include_top=False, weights='imagenet', input_tensor=inp)
    s1 = base.get_layer('conv1_relu').output
    s2 = base.get_layer('conv2_block3_out').output
    s3 = base.get_layer('conv3_block4_out').output
    s4 = base.get_layer('conv4_block6_out').output
    x  = base.get_layer('conv5_block3_out').output
    for skip, f in [(s4, 256), (s3, 128), (s2, 64), (s1, 32)]:
        x = tf.keras.layers.UpSampling2D(2)(x)
        x = tf.keras.layers.Concatenate()([x, skip])
        x = conv_block(x, f)
    x   = tf.keras.layers.UpSampling2D(2)(x)
    x   = conv_block(x, 16)
    out = tf.keras.layers.Conv2D(n_classes, 1, activation='softmax')(x)
    return tf.keras.Model(inp, out)

def build_unet_old(n_classes=N_CLASSES):
    inp  = tf.keras.Input((IMG_SIZE, IMG_SIZE, 3))
    base = tf.keras.applications.ResNet50(
        include_top=False, weights='imagenet', input_tensor=inp)
    base.trainable = False  # freeze encoder — avoids SM120 backward conv issue
    s1 = base.get_layer('conv1_relu').output
    s2 = base.get_layer('conv2_block3_out').output
    s3 = base.get_layer('conv3_block4_out').output
    s4 = base.get_layer('conv4_block6_out').output
    x  = base.get_layer('conv5_block3_out').output
    for skip, f in [(s4, 256), (s3, 128), (s2, 64), (s1, 32)]:
        x = tf.keras.layers.UpSampling2D(2)(x)
        x = tf.keras.layers.Concatenate()([x, skip])
        x = conv_block(x, f)
    x   = tf.keras.layers.UpSampling2D(2)(x)
    x   = conv_block(x, 16)
    out = tf.keras.layers.Conv2D(n_classes, 1, activation='softmax')(x)
    return tf.keras.Model(inp, out)


model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(LR),
    loss=vein_dice_ce_loss,
    metrics=[vein_iou, vein_dice],
    jit_compile=False
)

model.summary(line_length=80)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)          ┃ Output Shape      ┃     Param # ┃ Connected to       ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1         │ (None, 256, 256,  │           0 │ -                  │
# │ (InputLayer)          │ 3)                │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv1_pad             │ (None, 262, 262,  │           0 │ input_layer_1[0][… │
# │ (ZeroPadding2D)       │ 3)                │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv1_conv (Conv2D)   │ (None, 128, 128,  │       9,472 │ conv1_pad[0][0]    │
# │                       │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv1_bn              │ (None, 128, 128,  │         256 │ conv1_conv[0][0]   │
# │ (BatchNormalization)  │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv1_relu            │ (None, 128, 128,  │           0 │ conv1_bn[0][0]     │
# │ (Activation)          │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ pool1_pad             │ (None, 130, 130,  │           0 │ conv1_relu[0][0]   │
# │ (ZeroPadding2D)       │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ pool1_pool            │ (None, 64, 64,    │           0 │ pool1_pad[0][0]    │
# │ (MaxPooling2D)        │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_1_conv   │ (None, 64, 64,    │       4,160 │ pool1_pool[0][0]   │
# │ (Conv2D)              │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_1_bn     │ (None, 64, 64,    │         256 │ conv2_block1_1_co… │
# │ (BatchNormalization)  │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_1_relu   │ (None, 64, 64,    │           0 │ conv2_block1_1_bn… │
# │ (Activation)          │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_2_conv   │ (None, 64, 64,    │      36,928 │ conv2_block1_1_re… │
# │ (Conv2D)              │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_2_bn     │ (None, 64, 64,    │         256 │ conv2_block1_2_co… │
# │ (BatchNormalization)  │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_2_relu   │ (None, 64, 64,    │           0 │ conv2_block1_2_bn… │
# │ (Activation)          │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_0_conv   │ (None, 64, 64,    │      16,640 │ pool1_pool[0][0]   │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_3_conv   │ (None, 64, 64,    │      16,640 │ conv2_block1_2_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_0_bn     │ (None, 64, 64,    │       1,024 │ conv2_block1_0_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_3_bn     │ (None, 64, 64,    │       1,024 │ conv2_block1_3_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_add      │ (None, 64, 64,    │           0 │ conv2_block1_0_bn… │
# │ (Add)                 │ 256)              │             │ conv2_block1_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_out      │ (None, 64, 64,    │           0 │ conv2_block1_add[… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_1_conv   │ (None, 64, 64,    │      16,448 │ conv2_block1_out[… │
# │ (Conv2D)              │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_1_bn     │ (None, 64, 64,    │         256 │ conv2_block2_1_co… │
# │ (BatchNormalization)  │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_1_relu   │ (None, 64, 64,    │           0 │ conv2_block2_1_bn… │
# │ (Activation)          │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_2_conv   │ (None, 64, 64,    │      36,928 │ conv2_block2_1_re… │
# │ (Conv2D)              │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_2_bn     │ (None, 64, 64,    │         256 │ conv2_block2_2_co… │
# │ (BatchNormalization)  │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_2_relu   │ (None, 64, 64,    │           0 │ conv2_block2_2_bn… │
# │ (Activation)          │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_3_conv   │ (None, 64, 64,    │      16,640 │ conv2_block2_2_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_3_bn     │ (None, 64, 64,    │       1,024 │ conv2_block2_3_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_add      │ (None, 64, 64,    │           0 │ conv2_block1_out[… │
# │ (Add)                 │ 256)              │             │ conv2_block2_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_out      │ (None, 64, 64,    │           0 │ conv2_block2_add[… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_1_conv   │ (None, 64, 64,    │      16,448 │ conv2_block2_out[… │
# │ (Conv2D)              │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_1_bn     │ (None, 64, 64,    │         256 │ conv2_block3_1_co… │
# │ (BatchNormalization)  │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_1_relu   │ (None, 64, 64,    │           0 │ conv2_block3_1_bn… │
# │ (Activation)          │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_2_conv   │ (None, 64, 64,    │      36,928 │ conv2_block3_1_re… │
# │ (Conv2D)              │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_2_bn     │ (None, 64, 64,    │         256 │ conv2_block3_2_co… │
# │ (BatchNormalization)  │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_2_relu   │ (None, 64, 64,    │           0 │ conv2_block3_2_bn… │
# │ (Activation)          │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_3_conv   │ (None, 64, 64,    │      16,640 │ conv2_block3_2_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_3_bn     │ (None, 64, 64,    │       1,024 │ conv2_block3_3_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_add      │ (None, 64, 64,    │           0 │ conv2_block2_out[… │
# │ (Add)                 │ 256)              │             │ conv2_block3_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_out      │ (None, 64, 64,    │           0 │ conv2_block3_add[… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_1_conv   │ (None, 32, 32,    │      32,896 │ conv2_block3_out[… │
# │ (Conv2D)              │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_1_bn     │ (None, 32, 32,    │         512 │ conv3_block1_1_co… │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_1_relu   │ (None, 32, 32,    │           0 │ conv3_block1_1_bn… │
# │ (Activation)          │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_2_conv   │ (None, 32, 32,    │     147,584 │ conv3_block1_1_re… │
# │ (Conv2D)              │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_2_bn     │ (None, 32, 32,    │         512 │ conv3_block1_2_co… │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_2_relu   │ (None, 32, 32,    │           0 │ conv3_block1_2_bn… │
# │ (Activation)          │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_0_conv   │ (None, 32, 32,    │     131,584 │ conv2_block3_out[… │
# │ (Conv2D)              │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_3_conv   │ (None, 32, 32,    │      66,048 │ conv3_block1_2_re… │
# │ (Conv2D)              │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_0_bn     │ (None, 32, 32,    │       2,048 │ conv3_block1_0_co… │
# │ (BatchNormalization)  │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_3_bn     │ (None, 32, 32,    │       2,048 │ conv3_block1_3_co… │
# │ (BatchNormalization)  │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_add      │ (None, 32, 32,    │           0 │ conv3_block1_0_bn… │
# │ (Add)                 │ 512)              │             │ conv3_block1_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_out      │ (None, 32, 32,    │           0 │ conv3_block1_add[… │
# │ (Activation)          │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_1_conv   │ (None, 32, 32,    │      65,664 │ conv3_block1_out[… │
# │ (Conv2D)              │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_1_bn     │ (None, 32, 32,    │         512 │ conv3_block2_1_co… │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_1_relu   │ (None, 32, 32,    │           0 │ conv3_block2_1_bn… │
# │ (Activation)          │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_2_conv   │ (None, 32, 32,    │     147,584 │ conv3_block2_1_re… │
# │ (Conv2D)              │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_2_bn     │ (None, 32, 32,    │         512 │ conv3_block2_2_co… │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_2_relu   │ (None, 32, 32,    │           0 │ conv3_block2_2_bn… │
# │ (Activation)          │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_3_conv   │ (None, 32, 32,    │      66,048 │ conv3_block2_2_re… │
# │ (Conv2D)              │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_3_bn     │ (None, 32, 32,    │       2,048 │ conv3_block2_3_co… │
# │ (BatchNormalization)  │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_add      │ (None, 32, 32,    │           0 │ conv3_block1_out[… │
# │ (Add)                 │ 512)              │             │ conv3_block2_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_out      │ (None, 32, 32,    │           0 │ conv3_block2_add[… │
# │ (Activation)          │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_1_conv   │ (None, 32, 32,    │      65,664 │ conv3_block2_out[… │
# │ (Conv2D)              │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_1_bn     │ (None, 32, 32,    │         512 │ conv3_block3_1_co… │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_1_relu   │ (None, 32, 32,    │           0 │ conv3_block3_1_bn… │
# │ (Activation)          │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_2_conv   │ (None, 32, 32,    │     147,584 │ conv3_block3_1_re… │
# │ (Conv2D)              │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_2_bn     │ (None, 32, 32,    │         512 │ conv3_block3_2_co… │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_2_relu   │ (None, 32, 32,    │           0 │ conv3_block3_2_bn… │
# │ (Activation)          │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_3_conv   │ (None, 32, 32,    │      66,048 │ conv3_block3_2_re… │
# │ (Conv2D)              │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_3_bn     │ (None, 32, 32,    │       2,048 │ conv3_block3_3_co… │
# │ (BatchNormalization)  │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_add      │ (None, 32, 32,    │           0 │ conv3_block2_out[… │
# │ (Add)                 │ 512)              │             │ conv3_block3_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_out      │ (None, 32, 32,    │           0 │ conv3_block3_add[… │
# │ (Activation)          │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_1_conv   │ (None, 32, 32,    │      65,664 │ conv3_block3_out[… │
# │ (Conv2D)              │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_1_bn     │ (None, 32, 32,    │         512 │ conv3_block4_1_co… │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_1_relu   │ (None, 32, 32,    │           0 │ conv3_block4_1_bn… │
# │ (Activation)          │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_2_conv   │ (None, 32, 32,    │     147,584 │ conv3_block4_1_re… │
# │ (Conv2D)              │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_2_bn     │ (None, 32, 32,    │         512 │ conv3_block4_2_co… │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_2_relu   │ (None, 32, 32,    │           0 │ conv3_block4_2_bn… │
# │ (Activation)          │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_3_conv   │ (None, 32, 32,    │      66,048 │ conv3_block4_2_re… │
# │ (Conv2D)              │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_3_bn     │ (None, 32, 32,    │       2,048 │ conv3_block4_3_co… │
# │ (BatchNormalization)  │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_add      │ (None, 32, 32,    │           0 │ conv3_block3_out[… │
# │ (Add)                 │ 512)              │             │ conv3_block4_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_out      │ (None, 32, 32,    │           0 │ conv3_block4_add[… │
# │ (Activation)          │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_1_conv   │ (None, 16, 16,    │     131,328 │ conv3_block4_out[… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_1_bn     │ (None, 16, 16,    │       1,024 │ conv4_block1_1_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_1_relu   │ (None, 16, 16,    │           0 │ conv4_block1_1_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_2_conv   │ (None, 16, 16,    │     590,080 │ conv4_block1_1_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_2_bn     │ (None, 16, 16,    │       1,024 │ conv4_block1_2_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_2_relu   │ (None, 16, 16,    │           0 │ conv4_block1_2_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_0_conv   │ (None, 16, 16,    │     525,312 │ conv3_block4_out[… │
# │ (Conv2D)              │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_3_conv   │ (None, 16, 16,    │     263,168 │ conv4_block1_2_re… │
# │ (Conv2D)              │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_0_bn     │ (None, 16, 16,    │       4,096 │ conv4_block1_0_co… │
# │ (BatchNormalization)  │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_3_bn     │ (None, 16, 16,    │       4,096 │ conv4_block1_3_co… │
# │ (BatchNormalization)  │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_add      │ (None, 16, 16,    │           0 │ conv4_block1_0_bn… │
# │ (Add)                 │ 1024)             │             │ conv4_block1_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_out      │ (None, 16, 16,    │           0 │ conv4_block1_add[… │
# │ (Activation)          │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_1_conv   │ (None, 16, 16,    │     262,400 │ conv4_block1_out[… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_1_bn     │ (None, 16, 16,    │       1,024 │ conv4_block2_1_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_1_relu   │ (None, 16, 16,    │           0 │ conv4_block2_1_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_2_conv   │ (None, 16, 16,    │     590,080 │ conv4_block2_1_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_2_bn     │ (None, 16, 16,    │       1,024 │ conv4_block2_2_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_2_relu   │ (None, 16, 16,    │           0 │ conv4_block2_2_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_3_conv   │ (None, 16, 16,    │     263,168 │ conv4_block2_2_re… │
# │ (Conv2D)              │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_3_bn     │ (None, 16, 16,    │       4,096 │ conv4_block2_3_co… │
# │ (BatchNormalization)  │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_add      │ (None, 16, 16,    │           0 │ conv4_block1_out[… │
# │ (Add)                 │ 1024)             │             │ conv4_block2_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_out      │ (None, 16, 16,    │           0 │ conv4_block2_add[… │
# │ (Activation)          │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_1_conv   │ (None, 16, 16,    │     262,400 │ conv4_block2_out[… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_1_bn     │ (None, 16, 16,    │       1,024 │ conv4_block3_1_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_1_relu   │ (None, 16, 16,    │           0 │ conv4_block3_1_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_2_conv   │ (None, 16, 16,    │     590,080 │ conv4_block3_1_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_2_bn     │ (None, 16, 16,    │       1,024 │ conv4_block3_2_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_2_relu   │ (None, 16, 16,    │           0 │ conv4_block3_2_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_3_conv   │ (None, 16, 16,    │     263,168 │ conv4_block3_2_re… │
# │ (Conv2D)              │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_3_bn     │ (None, 16, 16,    │       4,096 │ conv4_block3_3_co… │
# │ (BatchNormalization)  │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_add      │ (None, 16, 16,    │           0 │ conv4_block2_out[… │
# │ (Add)                 │ 1024)             │             │ conv4_block3_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_out      │ (None, 16, 16,    │           0 │ conv4_block3_add[… │
# │ (Activation)          │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_1_conv   │ (None, 16, 16,    │     262,400 │ conv4_block3_out[… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_1_bn     │ (None, 16, 16,    │       1,024 │ conv4_block4_1_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_1_relu   │ (None, 16, 16,    │           0 │ conv4_block4_1_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_2_conv   │ (None, 16, 16,    │     590,080 │ conv4_block4_1_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_2_bn     │ (None, 16, 16,    │       1,024 │ conv4_block4_2_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_2_relu   │ (None, 16, 16,    │           0 │ conv4_block4_2_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_3_conv   │ (None, 16, 16,    │     263,168 │ conv4_block4_2_re… │
# │ (Conv2D)              │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_3_bn     │ (None, 16, 16,    │       4,096 │ conv4_block4_3_co… │
# │ (BatchNormalization)  │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_add      │ (None, 16, 16,    │           0 │ conv4_block3_out[… │
# │ (Add)                 │ 1024)             │             │ conv4_block4_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_out      │ (None, 16, 16,    │           0 │ conv4_block4_add[… │
# │ (Activation)          │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_1_conv   │ (None, 16, 16,    │     262,400 │ conv4_block4_out[… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_1_bn     │ (None, 16, 16,    │       1,024 │ conv4_block5_1_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_1_relu   │ (None, 16, 16,    │           0 │ conv4_block5_1_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_2_conv   │ (None, 16, 16,    │     590,080 │ conv4_block5_1_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_2_bn     │ (None, 16, 16,    │       1,024 │ conv4_block5_2_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_2_relu   │ (None, 16, 16,    │           0 │ conv4_block5_2_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_3_conv   │ (None, 16, 16,    │     263,168 │ conv4_block5_2_re… │
# │ (Conv2D)              │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_3_bn     │ (None, 16, 16,    │       4,096 │ conv4_block5_3_co… │
# │ (BatchNormalization)  │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_add      │ (None, 16, 16,    │           0 │ conv4_block4_out[… │
# │ (Add)                 │ 1024)             │             │ conv4_block5_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_out      │ (None, 16, 16,    │           0 │ conv4_block5_add[… │
# │ (Activation)          │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_1_conv   │ (None, 16, 16,    │     262,400 │ conv4_block5_out[… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_1_bn     │ (None, 16, 16,    │       1,024 │ conv4_block6_1_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_1_relu   │ (None, 16, 16,    │           0 │ conv4_block6_1_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_2_conv   │ (None, 16, 16,    │     590,080 │ conv4_block6_1_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_2_bn     │ (None, 16, 16,    │       1,024 │ conv4_block6_2_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_2_relu   │ (None, 16, 16,    │           0 │ conv4_block6_2_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_3_conv   │ (None, 16, 16,    │     263,168 │ conv4_block6_2_re… │
# │ (Conv2D)              │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_3_bn     │ (None, 16, 16,    │       4,096 │ conv4_block6_3_co… │
# │ (BatchNormalization)  │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_add      │ (None, 16, 16,    │           0 │ conv4_block5_out[… │
# │ (Add)                 │ 1024)             │             │ conv4_block6_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_out      │ (None, 16, 16,    │           0 │ conv4_block6_add[… │
# │ (Activation)          │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_1_conv   │ (None, 8, 8, 512) │     524,800 │ conv4_block6_out[… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_1_bn     │ (None, 8, 8, 512) │       2,048 │ conv5_block1_1_co… │
# │ (BatchNormalization)  │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_1_relu   │ (None, 8, 8, 512) │           0 │ conv5_block1_1_bn… │
# │ (Activation)          │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_2_conv   │ (None, 8, 8, 512) │   2,359,808 │ conv5_block1_1_re… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_2_bn     │ (None, 8, 8, 512) │       2,048 │ conv5_block1_2_co… │
# │ (BatchNormalization)  │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_2_relu   │ (None, 8, 8, 512) │           0 │ conv5_block1_2_bn… │
# │ (Activation)          │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_0_conv   │ (None, 8, 8,      │   2,099,200 │ conv4_block6_out[… │
# │ (Conv2D)              │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_3_conv   │ (None, 8, 8,      │   1,050,624 │ conv5_block1_2_re… │
# │ (Conv2D)              │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_0_bn     │ (None, 8, 8,      │       8,192 │ conv5_block1_0_co… │
# │ (BatchNormalization)  │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_3_bn     │ (None, 8, 8,      │       8,192 │ conv5_block1_3_co… │
# │ (BatchNormalization)  │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_add      │ (None, 8, 8,      │           0 │ conv5_block1_0_bn… │
# │ (Add)                 │ 2048)             │             │ conv5_block1_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_out      │ (None, 8, 8,      │           0 │ conv5_block1_add[… │
# │ (Activation)          │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_1_conv   │ (None, 8, 8, 512) │   1,049,088 │ conv5_block1_out[… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_1_bn     │ (None, 8, 8, 512) │       2,048 │ conv5_block2_1_co… │
# │ (BatchNormalization)  │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_1_relu   │ (None, 8, 8, 512) │           0 │ conv5_block2_1_bn… │
# │ (Activation)          │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_2_conv   │ (None, 8, 8, 512) │   2,359,808 │ conv5_block2_1_re… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_2_bn     │ (None, 8, 8, 512) │       2,048 │ conv5_block2_2_co… │
# │ (BatchNormalization)  │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_2_relu   │ (None, 8, 8, 512) │           0 │ conv5_block2_2_bn… │
# │ (Activation)          │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_3_conv   │ (None, 8, 8,      │   1,050,624 │ conv5_block2_2_re… │
# │ (Conv2D)              │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_3_bn     │ (None, 8, 8,      │       8,192 │ conv5_block2_3_co… │
# │ (BatchNormalization)  │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_add      │ (None, 8, 8,      │           0 │ conv5_block1_out[… │
# │ (Add)                 │ 2048)             │             │ conv5_block2_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_out      │ (None, 8, 8,      │           0 │ conv5_block2_add[… │
# │ (Activation)          │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_1_conv   │ (None, 8, 8, 512) │   1,049,088 │ conv5_block2_out[… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_1_bn     │ (None, 8, 8, 512) │       2,048 │ conv5_block3_1_co… │
# │ (BatchNormalization)  │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_1_relu   │ (None, 8, 8, 512) │           0 │ conv5_block3_1_bn… │
# │ (Activation)          │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_2_conv   │ (None, 8, 8, 512) │   2,359,808 │ conv5_block3_1_re… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_2_bn     │ (None, 8, 8, 512) │       2,048 │ conv5_block3_2_co… │
# │ (BatchNormalization)  │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_2_relu   │ (None, 8, 8, 512) │           0 │ conv5_block3_2_bn… │
# │ (Activation)          │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_3_conv   │ (None, 8, 8,      │   1,050,624 │ conv5_block3_2_re… │
# │ (Conv2D)              │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_3_bn     │ (None, 8, 8,      │       8,192 │ conv5_block3_3_co… │
# │ (BatchNormalization)  │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_add      │ (None, 8, 8,      │           0 │ conv5_block2_out[… │
# │ (Add)                 │ 2048)             │             │ conv5_block3_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_out      │ (None, 8, 8,      │           0 │ conv5_block3_add[… │
# │ (Activation)          │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ up_sampling2d_5       │ (None, 16, 16,    │           0 │ conv5_block3_out[… │
# │ (UpSampling2D)        │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ concatenate_4         │ (None, 16, 16,    │           0 │ up_sampling2d_5[0… │
# │ (Concatenate)         │ 3072)             │             │ conv4_block6_out[… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2d_11 (Conv2D)    │ (None, 16, 16,    │   7,077,888 │ concatenate_4[0][… │
# │                       │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ batch_normalization_… │ (None, 16, 16,    │       1,024 │ conv2d_11[0][0]    │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ re_lu_10 (ReLU)       │ (None, 16, 16,    │           0 │ batch_normalizati… │
# │                       │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2d_12 (Conv2D)    │ (None, 16, 16,    │     589,824 │ re_lu_10[0][0]     │
# │                       │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ batch_normalization_… │ (None, 16, 16,    │       1,024 │ conv2d_12[0][0]    │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ re_lu_11 (ReLU)       │ (None, 16, 16,    │           0 │ batch_normalizati… │
# │                       │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ up_sampling2d_6       │ (None, 32, 32,    │           0 │ re_lu_11[0][0]     │
# │ (UpSampling2D)        │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ concatenate_5         │ (None, 32, 32,    │           0 │ up_sampling2d_6[0… │
# │ (Concatenate)         │ 768)              │             │ conv3_block4_out[… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2d_13 (Conv2D)    │ (None, 32, 32,    │     884,736 │ concatenate_5[0][… │
# │                       │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ batch_normalization_… │ (None, 32, 32,    │         512 │ conv2d_13[0][0]    │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ re_lu_12 (ReLU)       │ (None, 32, 32,    │           0 │ batch_normalizati… │
# │                       │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2d_14 (Conv2D)    │ (None, 32, 32,    │     147,456 │ re_lu_12[0][0]     │
# │                       │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ batch_normalization_… │ (None, 32, 32,    │         512 │ conv2d_14[0][0]    │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ re_lu_13 (ReLU)       │ (None, 32, 32,    │           0 │ batch_normalizati… │
# │                       │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ up_sampling2d_7       │ (None, 64, 64,    │           0 │ re_lu_13[0][0]     │
# │ (UpSampling2D)        │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ concatenate_6         │ (None, 64, 64,    │           0 │ up_sampling2d_7[0… │
# │ (Concatenate)         │ 384)              │             │ conv2_block3_out[… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2d_15 (Conv2D)    │ (None, 64, 64,    │     221,184 │ concatenate_6[0][… │
# │                       │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ batch_normalization_… │ (None, 64, 64,    │         256 │ conv2d_15[0][0]    │
# │ (BatchNormalization)  │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ re_lu_14 (ReLU)       │ (None, 64, 64,    │           0 │ batch_normalizati… │
# │                       │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2d_16 (Conv2D)    │ (None, 64, 64,    │      36,864 │ re_lu_14[0][0]     │
# │                       │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ batch_normalization_… │ (None, 64, 64,    │         256 │ conv2d_16[0][0]    │
# │ (BatchNormalization)  │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ re_lu_15 (ReLU)       │ (None, 64, 64,    │           0 │ batch_normalizati… │
# │                       │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ up_sampling2d_8       │ (None, 128, 128,  │           0 │ re_lu_15[0][0]     │
# │ (UpSampling2D)        │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ concatenate_7         │ (None, 128, 128,  │           0 │ up_sampling2d_8[0… │
# │ (Concatenate)         │ 128)              │             │ conv1_relu[0][0]   │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2d_17 (Conv2D)    │ (None, 128, 128,  │      36,864 │ concatenate_7[0][… │
# │                       │ 32)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ batch_normalization_… │ (None, 128, 128,  │         128 │ conv2d_17[0][0]    │
# │ (BatchNormalization)  │ 32)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ re_lu_16 (ReLU)       │ (None, 128, 128,  │           0 │ batch_normalizati… │
# │                       │ 32)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2d_18 (Conv2D)    │ (None, 128, 128,  │       9,216 │ re_lu_16[0][0]     │
# │                       │ 32)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ batch_normalization_… │ (None, 128, 128,  │         128 │ conv2d_18[0][0]    │
# │ (BatchNormalization)  │ 32)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ re_lu_17 (ReLU)       │ (None, 128, 128,  │           0 │ batch_normalizati… │
# │                       │ 32)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ up_sampling2d_9       │ (None, 256, 256,  │           0 │ re_lu_17[0][0]     │
# │ (UpSampling2D)        │ 32)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2d_19 (Conv2D)    │ (None, 256, 256,  │       4,608 │ up_sampling2d_9[0… │
# │                       │ 16)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ batch_normalization_… │ (None, 256, 256,  │          64 │ conv2d_19[0][0]    │
# │ (BatchNormalization)  │ 16)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ re_lu_18 (ReLU)       │ (None, 256, 256,  │           0 │ batch_normalizati… │
# │                       │ 16)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2d_20 (Conv2D)    │ (None, 256, 256,  │       2,304 │ re_lu_18[0][0]     │
# │                       │ 16)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ batch_normalization_… │ (None, 256, 256,  │          64 │ conv2d_20[0][0]    │
# │ (BatchNormalization)  │ 16)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ re_lu_19 (ReLU)       │ (None, 256, 256,  │           0 │ batch_normalizati… │
# │                       │ 16)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2d_21 (Conv2D)    │ (None, 256, 256,  │          34 │ re_lu_19[0][0]     │
# │                       │ 2)                │             │                    │
# └───────────────────────┴───────────────────┴─────────────┴────────────────────┘
#  Total params: 32,602,658 (124.37 MB)
#  Trainable params: 32,547,554 (124.16 MB)
#  Non-trainable params: 55,104 (215.25 KB)

# %%
CKPT_PATH = str(CKPT_DIR / 'unet_resnet50_vein_best.keras')

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        CKPT_PATH,
        monitor='val_vein_iou', mode='max',
        save_best_only=True, verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_vein_iou', mode='max',
        factor=0.5, patience=8, min_lr=1e-6, verbose=1),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_vein_iou', mode='max',
        patience=15, restore_best_weights=True, verbose=1),
    tf.keras.callbacks.CSVLogger(
        str(VEIN_DIR / 'training_log.csv'), append=True),
]

t0 = time.time()
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)
print(f'Training done in {(time.time()-t0)/60:.1f} min')
# Out:
# Epoch 1/60
# W0000 00:00:1779943605.492384    4430 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.492478    4435 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.492470    4428 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.492500    4434 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.492490    4427 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.492515    4433 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.492526    4432 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.493407    4426 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.591548    4459 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.593011    4458 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.593927    4454 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.595672    4452 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.597060    4455 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.598513    4460 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.600009    4453 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.600938    4457 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.644655    4141 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.738001    4139 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943605.774066    4139 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943606.314745    4139 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# W0000 00:00:1779943606.358451    4139 gpu_kernel_to_blob_pass.cc:190] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.4028 - vein_dice: 0.4456 - vein_iou: 0.3385
# Epoch 1: val_vein_iou improved from None to 0.00000, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 1: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 43s 137ms/step - loss: 0.3363 - vein_dice: 0.6714 - vein_iou: 0.5486 - val_loss: 0.5358 - val_vein_dice: 0.0000e+00 - val_vein_iou: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 2/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.2683 - vein_dice: 0.8673 - vein_iou: 0.7675
# Epoch 2: val_vein_iou improved from 0.00000 to 0.32077, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 2: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 28s 131ms/step - loss: 0.2613 - vein_dice: 0.8723 - vein_iou: 0.7752 - val_loss: 0.4608 - val_vein_dice: 0.4613 - val_vein_iou: 0.3208 - learning_rate: 1.0000e-04
# Epoch 3/60
# 198/217 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - loss: 0.2423 - vein_dice: 0.8858 - vein_iou: 0.7967
# Epoch 3: val_vein_iou improved from 0.32077 to 0.71921, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 3: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 28s 131ms/step - loss: 0.2361 - vein_dice: 0.8923 - vein_iou: 0.8068 - val_loss: 0.2921 - val_vein_dice: 0.8331 - val_vein_iou: 0.7192 - learning_rate: 1.0000e-04
# Epoch 4/60
# 208/217 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - loss: 0.2196 - vein_dice: 0.9031 - vein_iou: 0.8242
# Epoch 4: val_vein_iou improved from 0.71921 to 0.83461, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 4: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 28s 130ms/step - loss: 0.2132 - vein_dice: 0.9065 - vein_iou: 0.8299 - val_loss: 0.2175 - val_vein_dice: 0.9095 - val_vein_iou: 0.8346 - learning_rate: 1.0000e-04
# Epoch 5/60
# 214/217 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.1944 - vein_dice: 0.9178 - vein_iou: 0.8489
# Epoch 5: val_vein_iou did not improve from 0.83461
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 28s 127ms/step - loss: 0.1910 - vein_dice: 0.9065 - vein_iou: 0.8316 - val_loss: 0.2058 - val_vein_dice: 0.8307 - val_vein_iou: 0.7124 - learning_rate: 1.0000e-04
# Epoch 6/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.1752 - vein_dice: 0.9036 - vein_iou: 0.8260
# Epoch 6: val_vein_iou improved from 0.83461 to 0.87557, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 6: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 31s 144ms/step - loss: 0.1671 - vein_dice: 0.9125 - vein_iou: 0.8406 - val_loss: 0.1533 - val_vein_dice: 0.9334 - val_vein_iou: 0.8756 - learning_rate: 1.0000e-04
# Epoch 7/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.1491 - vein_dice: 0.9251 - vein_iou: 0.8616
# Epoch 7: val_vein_iou improved from 0.87557 to 0.87718, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 7: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 28s 130ms/step - loss: 0.1417 - vein_dice: 0.9288 - vein_iou: 0.8679 - val_loss: 0.1301 - val_vein_dice: 0.9343 - val_vein_iou: 0.8772 - learning_rate: 1.0000e-04
# Epoch 8/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.1241 - vein_dice: 0.9370 - vein_iou: 0.8819
# Epoch 8: val_vein_iou improved from 0.87718 to 0.88712, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 8: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 28s 128ms/step - loss: 0.1188 - vein_dice: 0.9363 - vein_iou: 0.8807 - val_loss: 0.1077 - val_vein_dice: 0.9399 - val_vein_iou: 0.8871 - learning_rate: 1.0000e-04
# Epoch 9/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.1033 - vein_dice: 0.9385 - vein_iou: 0.8848
# Epoch 9: val_vein_iou did not improve from 0.88712
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 122ms/step - loss: 0.1011 - vein_dice: 0.9332 - vein_iou: 0.8757 - val_loss: 0.0965 - val_vein_dice: 0.8956 - val_vein_iou: 0.8121 - learning_rate: 1.0000e-04
# Epoch 10/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0865 - vein_dice: 0.9398 - vein_iou: 0.8871
# Epoch 10: val_vein_iou did not improve from 0.88712
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 125ms/step - loss: 0.0823 - vein_dice: 0.9401 - vein_iou: 0.8877 - val_loss: 0.0764 - val_vein_dice: 0.9266 - val_vein_iou: 0.8638 - learning_rate: 1.0000e-04
# Epoch 11/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0707 - vein_dice: 0.9418 - vein_iou: 0.8908
# Epoch 11: val_vein_iou improved from 0.88712 to 0.90477, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 11: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 28s 130ms/step - loss: 0.0677 - vein_dice: 0.9394 - vein_iou: 0.8867 - val_loss: 0.0677 - val_vein_dice: 0.9498 - val_vein_iou: 0.9048 - learning_rate: 1.0000e-04
# Epoch 12/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0573 - vein_dice: 0.9464 - vein_iou: 0.8986
# Epoch 12: val_vein_iou did not improve from 0.90477
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - loss: 0.0544 - vein_dice: 0.9480 - vein_iou: 0.9017 - val_loss: 0.0531 - val_vein_dice: 0.9492 - val_vein_iou: 0.9038 - learning_rate: 1.0000e-04
# Epoch 13/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0482 - vein_dice: 0.9500 - vein_iou: 0.9052
# Epoch 13: val_vein_iou did not improve from 0.90477
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 122ms/step - loss: 0.0477 - vein_dice: 0.9468 - vein_iou: 0.8997 - val_loss: 0.0800 - val_vein_dice: 0.8772 - val_vein_iou: 0.7839 - learning_rate: 1.0000e-04
# Epoch 14/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0424 - vein_dice: 0.9491 - vein_iou: 0.9035
# Epoch 14: val_vein_iou improved from 0.90477 to 0.91046, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 14: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 126ms/step - loss: 0.0405 - vein_dice: 0.9504 - vein_iou: 0.9058 - val_loss: 0.0432 - val_vein_dice: 0.9529 - val_vein_iou: 0.9105 - learning_rate: 1.0000e-04
# Epoch 15/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0361 - vein_dice: 0.9537 - vein_iou: 0.9119
# Epoch 15: val_vein_iou did not improve from 0.91046
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 122ms/step - loss: 0.0350 - vein_dice: 0.9545 - vein_iou: 0.9133 - val_loss: 0.0375 - val_vein_dice: 0.9490 - val_vein_iou: 0.9034 - learning_rate: 1.0000e-04
# Epoch 16/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0313 - vein_dice: 0.9581 - vein_iou: 0.9198
# Epoch 16: val_vein_iou improved from 0.91046 to 0.91208, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 16: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 28s 130ms/step - loss: 0.0306 - vein_dice: 0.9583 - vein_iou: 0.9202 - val_loss: 0.0361 - val_vein_dice: 0.9538 - val_vein_iou: 0.9121 - learning_rate: 1.0000e-04
# Epoch 17/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0280 - vein_dice: 0.9607 - vein_iou: 0.9246
# Epoch 17: val_vein_iou did not improve from 0.91208
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 124ms/step - loss: 0.0274 - vein_dice: 0.9606 - vein_iou: 0.9245 - val_loss: 0.0351 - val_vein_dice: 0.9536 - val_vein_iou: 0.9118 - learning_rate: 1.0000e-04
# Epoch 18/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0258 - vein_dice: 0.9606 - vein_iou: 0.9244
# Epoch 18: val_vein_iou did not improve from 0.91208
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - loss: 0.0265 - vein_dice: 0.9567 - vein_iou: 0.9181 - val_loss: 0.0319 - val_vein_dice: 0.9376 - val_vein_iou: 0.8831 - learning_rate: 1.0000e-04
# Epoch 19/60
# 205/217 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - loss: 0.0263 - vein_dice: 0.9562 - vein_iou: 0.9165
# Epoch 19: val_vein_iou did not improve from 0.91208
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 122ms/step - loss: 0.0251 - vein_dice: 0.9583 - vein_iou: 0.9203 - val_loss: 0.0303 - val_vein_dice: 0.9530 - val_vein_iou: 0.9107 - learning_rate: 1.0000e-04
# Epoch 20/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0224 - vein_dice: 0.9637 - vein_iou: 0.9302
# Epoch 20: val_vein_iou did not improve from 0.91208
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 30s 139ms/step - loss: 0.0223 - vein_dice: 0.9625 - vein_iou: 0.9278 - val_loss: 0.0295 - val_vein_dice: 0.9516 - val_vein_iou: 0.9081 - learning_rate: 1.0000e-04
# Epoch 21/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0216 - vein_dice: 0.9621 - vein_iou: 0.9272
# Epoch 21: val_vein_iou improved from 0.91208 to 0.91359, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 21: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 28s 130ms/step - loss: 0.0212 - vein_dice: 0.9624 - vein_iou: 0.9277 - val_loss: 0.0304 - val_vein_dice: 0.9546 - val_vein_iou: 0.9136 - learning_rate: 1.0000e-04
# Epoch 22/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0197 - vein_dice: 0.9646 - vein_iou: 0.9319
# Epoch 22: val_vein_iou did not improve from 0.91359
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 124ms/step - loss: 0.0196 - vein_dice: 0.9643 - vein_iou: 0.9312 - val_loss: 0.0272 - val_vein_dice: 0.9529 - val_vein_iou: 0.9104 - learning_rate: 1.0000e-04
# Epoch 23/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0185 - vein_dice: 0.9660 - vein_iou: 0.9344
# Epoch 23: val_vein_iou did not improve from 0.91359
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 124ms/step - loss: 0.0187 - vein_dice: 0.9649 - vein_iou: 0.9324 - val_loss: 0.0275 - val_vein_dice: 0.9448 - val_vein_iou: 0.8958 - learning_rate: 1.0000e-04
# Epoch 24/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0178 - vein_dice: 0.9655 - vein_iou: 0.9334
# Epoch 24: val_vein_iou did not improve from 0.91359
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 26s 122ms/step - loss: 0.0176 - vein_dice: 0.9661 - vein_iou: 0.9347 - val_loss: 0.0262 - val_vein_dice: 0.9537 - val_vein_iou: 0.9118 - learning_rate: 1.0000e-04
# Epoch 25/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0167 - vein_dice: 0.9678 - vein_iou: 0.9378
# Epoch 25: val_vein_iou did not improve from 0.91359
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 125ms/step - loss: 0.0167 - vein_dice: 0.9676 - vein_iou: 0.9373 - val_loss: 0.0265 - val_vein_dice: 0.9540 - val_vein_iou: 0.9124 - learning_rate: 1.0000e-04
# Epoch 26/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0156 - vein_dice: 0.9698 - vein_iou: 0.9414
# Epoch 26: val_vein_iou improved from 0.91359 to 0.91610, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 26: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 28s 129ms/step - loss: 0.0156 - vein_dice: 0.9694 - vein_iou: 0.9407 - val_loss: 0.0259 - val_vein_dice: 0.9560 - val_vein_iou: 0.9161 - learning_rate: 1.0000e-04
# Epoch 27/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0149 - vein_dice: 0.9707 - vein_iou: 0.9431
# Epoch 27: val_vein_iou did not improve from 0.91610
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 125ms/step - loss: 0.0154 - vein_dice: 0.9693 - vein_iou: 0.9406 - val_loss: 0.0264 - val_vein_dice: 0.9524 - val_vein_iou: 0.9098 - learning_rate: 1.0000e-04
# Epoch 28/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0189 - vein_dice: 0.9613 - vein_iou: 0.9262
# Epoch 28: val_vein_iou did not improve from 0.91610
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 126ms/step - loss: 0.0214 - vein_dice: 0.9549 - vein_iou: 0.9145 - val_loss: 0.0304 - val_vein_dice: 0.9425 - val_vein_iou: 0.8917 - learning_rate: 1.0000e-04
# Epoch 29/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0169 - vein_dice: 0.9641 - vein_iou: 0.9309
# Epoch 29: val_vein_iou did not improve from 0.91610
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - loss: 0.0168 - vein_dice: 0.9646 - vein_iou: 0.9318 - val_loss: 0.0251 - val_vein_dice: 0.9518 - val_vein_iou: 0.9088 - learning_rate: 1.0000e-04
# Epoch 30/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0170 - vein_dice: 0.9632 - vein_iou: 0.9294
# Epoch 30: val_vein_iou improved from 0.91610 to 0.92039, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 30: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 28s 130ms/step - loss: 0.0163 - vein_dice: 0.9648 - vein_iou: 0.9325 - val_loss: 0.0238 - val_vein_dice: 0.9584 - val_vein_iou: 0.9204 - learning_rate: 1.0000e-04
# Epoch 31/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0146 - vein_dice: 0.9688 - vein_iou: 0.9397
# Epoch 31: val_vein_iou did not improve from 0.92039
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 124ms/step - loss: 0.0143 - vein_dice: 0.9695 - vein_iou: 0.9411 - val_loss: 0.0229 - val_vein_dice: 0.9578 - val_vein_iou: 0.9193 - learning_rate: 1.0000e-04
# Epoch 32/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0132 - vein_dice: 0.9720 - vein_iou: 0.9456
# Epoch 32: val_vein_iou improved from 0.92039 to 0.92619, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 32: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 28s 129ms/step - loss: 0.0133 - vein_dice: 0.9719 - vein_iou: 0.9454 - val_loss: 0.0239 - val_vein_dice: 0.9615 - val_vein_iou: 0.9262 - learning_rate: 1.0000e-04
# Epoch 33/60
# 199/217 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - loss: 0.0124 - vein_dice: 0.9739 - vein_iou: 0.9492
# Epoch 33: val_vein_iou did not improve from 0.92619
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - loss: 0.0128 - vein_dice: 0.9728 - vein_iou: 0.9472 - val_loss: 0.0226 - val_vein_dice: 0.9507 - val_vein_iou: 0.9065 - learning_rate: 1.0000e-04
# Epoch 34/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0131 - vein_dice: 0.9718 - vein_iou: 0.9454
# Epoch 34: val_vein_iou did not improve from 0.92619
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 124ms/step - loss: 0.0126 - vein_dice: 0.9729 - vein_iou: 0.9474 - val_loss: 0.0217 - val_vein_dice: 0.9608 - val_vein_iou: 0.9249 - learning_rate: 1.0000e-04
# Epoch 35/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0119 - vein_dice: 0.9741 - vein_iou: 0.9497
# Epoch 35: val_vein_iou did not improve from 0.92619
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 30s 138ms/step - loss: 0.0118 - vein_dice: 0.9746 - vein_iou: 0.9505 - val_loss: 0.0222 - val_vein_dice: 0.9597 - val_vein_iou: 0.9229 - learning_rate: 1.0000e-04
# Epoch 36/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0113 - vein_dice: 0.9756 - vein_iou: 0.9523
# Epoch 36: val_vein_iou did not improve from 0.92619
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - loss: 0.0113 - vein_dice: 0.9757 - vein_iou: 0.9526 - val_loss: 0.0226 - val_vein_dice: 0.9598 - val_vein_iou: 0.9231 - learning_rate: 1.0000e-04
# Epoch 37/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0108 - vein_dice: 0.9768 - vein_iou: 0.9548
# Epoch 37: val_vein_iou did not improve from 0.92619
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 124ms/step - loss: 0.0110 - vein_dice: 0.9760 - vein_iou: 0.9534 - val_loss: 0.0251 - val_vein_dice: 0.9594 - val_vein_iou: 0.9224 - learning_rate: 1.0000e-04
# Epoch 38/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0108 - vein_dice: 0.9763 - vein_iou: 0.9539
# Epoch 38: val_vein_iou did not improve from 0.92619
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - loss: 0.0108 - vein_dice: 0.9765 - vein_iou: 0.9542 - val_loss: 0.0232 - val_vein_dice: 0.9582 - val_vein_iou: 0.9201 - learning_rate: 1.0000e-04
# Epoch 39/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0103 - vein_dice: 0.9774 - vein_iou: 0.9559
# Epoch 39: val_vein_iou improved from 0.92619 to 0.92627, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 39: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 28s 130ms/step - loss: 0.0104 - vein_dice: 0.9772 - vein_iou: 0.9555 - val_loss: 0.0244 - val_vein_dice: 0.9615 - val_vein_iou: 0.9263 - learning_rate: 1.0000e-04
# Epoch 40/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0099 - vein_dice: 0.9787 - vein_iou: 0.9583
# Epoch 40: val_vein_iou did not improve from 0.92627
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 125ms/step - loss: 0.0100 - vein_dice: 0.9781 - vein_iou: 0.9571 - val_loss: 0.0250 - val_vein_dice: 0.9603 - val_vein_iou: 0.9239 - learning_rate: 1.0000e-04
# Epoch 41/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0093 - vein_dice: 0.9797 - vein_iou: 0.9603
# Epoch 41: val_vein_iou did not improve from 0.92627
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 122ms/step - loss: 0.0097 - vein_dice: 0.9790 - vein_iou: 0.9590 - val_loss: 0.0237 - val_vein_dice: 0.9603 - val_vein_iou: 0.9240 - learning_rate: 5.0000e-05
# Epoch 42/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0094 - vein_dice: 0.9793 - vein_iou: 0.9596
# Epoch 42: val_vein_iou improved from 0.92627 to 0.92966, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 42: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 29s 132ms/step - loss: 0.0094 - vein_dice: 0.9795 - vein_iou: 0.9598 - val_loss: 0.0229 - val_vein_dice: 0.9634 - val_vein_iou: 0.9297 - learning_rate: 5.0000e-05
# Epoch 43/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0088 - vein_dice: 0.9806 - vein_iou: 0.9620
# Epoch 43: val_vein_iou did not improve from 0.92966
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 127ms/step - loss: 0.0088 - vein_dice: 0.9809 - vein_iou: 0.9626 - val_loss: 0.0244 - val_vein_dice: 0.9634 - val_vein_iou: 0.9296 - learning_rate: 5.0000e-05
# Epoch 44/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0081 - vein_dice: 0.9825 - vein_iou: 0.9656
# Epoch 44: val_vein_iou did not improve from 0.92966
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - loss: 0.0083 - vein_dice: 0.9819 - vein_iou: 0.9644 - val_loss: 0.0240 - val_vein_dice: 0.9622 - val_vein_iou: 0.9275 - learning_rate: 5.0000e-05
# Epoch 45/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0082 - vein_dice: 0.9819 - vein_iou: 0.9645
# Epoch 45: val_vein_iou improved from 0.92966 to 0.92991, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 45: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 28s 130ms/step - loss: 0.0081 - vein_dice: 0.9823 - vein_iou: 0.9653 - val_loss: 0.0247 - val_vein_dice: 0.9635 - val_vein_iou: 0.9299 - learning_rate: 5.0000e-05
# Epoch 46/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0077 - vein_dice: 0.9834 - vein_iou: 0.9673
# Epoch 46: val_vein_iou did not improve from 0.92991
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - loss: 0.0077 - vein_dice: 0.9832 - vein_iou: 0.9669 - val_loss: 0.0244 - val_vein_dice: 0.9634 - val_vein_iou: 0.9297 - learning_rate: 5.0000e-05
# Epoch 47/60
# 204/217 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 0.0075 - vein_dice: 0.9836 - vein_iou: 0.9678
# Epoch 47: val_vein_iou did not improve from 0.92991
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 124ms/step - loss: 0.0075 - vein_dice: 0.9835 - vein_iou: 0.9676 - val_loss: 0.0245 - val_vein_dice: 0.9630 - val_vein_iou: 0.9290 - learning_rate: 5.0000e-05
# Epoch 48/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0077 - vein_dice: 0.9831 - vein_iou: 0.9668
# Epoch 48: val_vein_iou improved from 0.92991 to 0.93002, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 48: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 28s 131ms/step - loss: 0.0076 - vein_dice: 0.9832 - vein_iou: 0.9671 - val_loss: 0.0247 - val_vein_dice: 0.9636 - val_vein_iou: 0.9300 - learning_rate: 5.0000e-05
# Epoch 49/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.0073 - vein_dice: 0.9837 - vein_iou: 0.9680
# Epoch 49: val_vein_iou improved from 0.93002 to 0.93023, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 49: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 30s 139ms/step - loss: 0.0073 - vein_dice: 0.9839 - vein_iou: 0.9683 - val_loss: 0.0268 - val_vein_dice: 0.9637 - val_vein_iou: 0.9302 - learning_rate: 5.0000e-05
# Epoch 50/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0069 - vein_dice: 0.9848 - vein_iou: 0.9701
# Epoch 50: val_vein_iou improved from 0.93023 to 0.93173, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 50: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 125ms/step - loss: 0.0070 - vein_dice: 0.9845 - vein_iou: 0.9694 - val_loss: 0.0257 - val_vein_dice: 0.9645 - val_vein_iou: 0.9317 - learning_rate: 5.0000e-05
# Epoch 51/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0071 - vein_dice: 0.9841 - vein_iou: 0.9687
# Epoch 51: val_vein_iou did not improve from 0.93173
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 26s 120ms/step - loss: 0.0070 - vein_dice: 0.9842 - vein_iou: 0.9690 - val_loss: 0.0269 - val_vein_dice: 0.9634 - val_vein_iou: 0.9297 - learning_rate: 5.0000e-05
# Epoch 52/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0067 - vein_dice: 0.9851 - vein_iou: 0.9707
# Epoch 52: val_vein_iou did not improve from 0.93173
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 26s 120ms/step - loss: 0.0068 - vein_dice: 0.9846 - vein_iou: 0.9698 - val_loss: 0.0267 - val_vein_dice: 0.9629 - val_vein_iou: 0.9287 - learning_rate: 5.0000e-05
# Epoch 53/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0067 - vein_dice: 0.9847 - vein_iou: 0.9699
# Epoch 53: val_vein_iou did not improve from 0.93173
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 124ms/step - loss: 0.0067 - vein_dice: 0.9848 - vein_iou: 0.9700 - val_loss: 0.0272 - val_vein_dice: 0.9632 - val_vein_iou: 0.9293 - learning_rate: 5.0000e-05
# Epoch 54/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0065 - vein_dice: 0.9850 - vein_iou: 0.9706
# Epoch 54: val_vein_iou did not improve from 0.93173
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 26s 121ms/step - loss: 0.0064 - vein_dice: 0.9853 - vein_iou: 0.9711 - val_loss: 0.0279 - val_vein_dice: 0.9631 - val_vein_iou: 0.9292 - learning_rate: 5.0000e-05
# Epoch 55/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0062 - vein_dice: 0.9858 - vein_iou: 0.9720
# Epoch 55: val_vein_iou did not improve from 0.93173
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - loss: 0.0062 - vein_dice: 0.9858 - vein_iou: 0.9720 - val_loss: 0.0301 - val_vein_dice: 0.9633 - val_vein_iou: 0.9295 - learning_rate: 5.0000e-05
# Epoch 56/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0064 - vein_dice: 0.9851 - vein_iou: 0.9707
# Epoch 56: val_vein_iou did not improve from 0.93173
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 125ms/step - loss: 0.0062 - vein_dice: 0.9857 - vein_iou: 0.9718 - val_loss: 0.0276 - val_vein_dice: 0.9639 - val_vein_iou: 0.9306 - learning_rate: 5.0000e-05
# Epoch 57/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0060 - vein_dice: 0.9862 - vein_iou: 0.9727
# Epoch 57: val_vein_iou did not improve from 0.93173
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - loss: 0.0059 - vein_dice: 0.9862 - vein_iou: 0.9727 - val_loss: 0.0296 - val_vein_dice: 0.9644 - val_vein_iou: 0.9315 - learning_rate: 5.0000e-05
# Epoch 58/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0059 - vein_dice: 0.9863 - vein_iou: 0.9730
# Epoch 58: val_vein_iou did not improve from 0.93173
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 26s 121ms/step - loss: 0.0059 - vein_dice: 0.9862 - vein_iou: 0.9728 - val_loss: 0.0293 - val_vein_dice: 0.9632 - val_vein_iou: 0.9293 - learning_rate: 5.0000e-05
# Epoch 59/60
# 209/217 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - loss: 0.0053 - vein_dice: 0.9876 - vein_iou: 0.9756
# Epoch 59: val_vein_iou did not improve from 0.93173
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 26s 122ms/step - loss: 0.0053 - vein_dice: 0.9877 - vein_iou: 0.9756 - val_loss: 0.0285 - val_vein_dice: 0.9642 - val_vein_iou: 0.9311 - learning_rate: 2.5000e-05
# Epoch 60/60
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0050 - vein_dice: 0.9884 - vein_iou: 0.9770
# Epoch 60: val_vein_iou improved from 0.93173 to 0.93178, saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
#
# Epoch 60: finished saving model to /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 29s 132ms/step - loss: 0.0049 - vein_dice: 0.9886 - vein_iou: 0.9775 - val_loss: 0.0301 - val_vein_dice: 0.9645 - val_vein_iou: 0.9318 - learning_rate: 2.5000e-05
# Restoring model weights from the end of the best epoch: 60.
# Training done in 27.7 min

# %%
log_df = pd.read_csv(VEIN_DIR / 'training_log.csv')

fig, axes = plt.subplots(1, 3, figsize=(16, 4))
pairs = [
    ('loss',      'val_loss',      'Loss'),
    ('vein_iou',  'val_vein_iou',  'Vein IoU'),
    ('vein_dice', 'val_vein_dice', 'Vein Dice'),
]
for ax, (tr, vl, title) in zip(axes, pairs):
    ax.plot(log_df['epoch'], log_df[tr], label='Train')
    ax.plot(log_df['epoch'], log_df[vl], label='Val')
    ax.set_title(title); ax.set_xlabel('Epoch'); ax.legend(); ax.grid(True)
plt.tight_layout()
plt.savefig(str(PLOT_DIR / 'training_curves.png'), dpi=150, bbox_inches='tight')
plt.show()
best_ep  = int(log_df['val_vein_iou'].idxmax())
best_iou = float(log_df['val_vein_iou'].max())
print(f'Best val_vein_iou: {best_iou:.4f}  at epoch {best_ep}')
# Out:
# Best val_vein_iou: 0.9318  at epoch 59

# %%
best_model = tf.keras.models.load_model(
    CKPT_PATH,
    custom_objects={
        'vein_dice_ce_loss': vein_dice_ce_loss,
        'vein_iou': vein_iou,
        'vein_dice': vein_dice
    })

print('Evaluating on validation set...')
results = best_model.evaluate(val_ds, verbose=1)
print(dict(zip(best_model.metrics_names, results)))

n_show = 6
sample = val_df.sample(n_show, random_state=SEED).reset_index(drop=True)

fig, axes = plt.subplots(n_show, 3, figsize=(10, n_show * 3))
for i, row in sample.iterrows():
    raw  = cv2.cvtColor(cv2.imread(row['frame_path']), cv2.COLOR_BGR2RGB)
    raw  = cv2.resize(raw, (IMG_SIZE, IMG_SIZE))
    gt   = (cv2.imread(row['mask_path'], cv2.IMREAD_GRAYSCALE) > 0).astype(np.uint8)
    inp  = ((raw.astype(np.float32) / 255. - MEAN_NP) / STD_NP)[None]
    pred = best_model.predict(inp, verbose=0)[0]
    pred_mask = np.argmax(pred, -1).astype(np.uint8)

    axes[i, 0].imshow(raw);                axes[i, 0].set_title('Frame')
    axes[i, 1].imshow(gt,        cmap='gray'); axes[i, 1].set_title('GT Mask')
    axes[i, 2].imshow(pred_mask, cmap='gray'); axes[i, 2].set_title('Predicted')
    for ax in axes[i]: ax.axis('off')

plt.tight_layout()
plt.savefig(str(PLOT_DIR / 'sample_predictions.png'), dpi=120, bbox_inches='tight')
plt.show()
# Out:
# Evaluating on validation set...
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0301 - vein_dice: 0.9645 - vein_iou: 0.9318
# {'loss': 0.03011971525847912, 'compile_metrics': 0.9317797422409058}

# %%
ious, dices = [], []
for _, row in val_df.iterrows():
    raw  = cv2.cvtColor(cv2.imread(row['frame_path']), cv2.COLOR_BGR2RGB)
    raw  = cv2.resize(raw, (IMG_SIZE, IMG_SIZE))
    gt   = cv2.imread(row['mask_path'], cv2.IMREAD_GRAYSCALE)
    gt   = cv2.resize(gt, (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_NEAREST)
    gt   = (gt > 0).astype(np.int32).flatten()
    inp  = ((raw.astype(np.float32) / 255. - MEAN_NP) / STD_NP)[None]
    pred = np.argmax(best_model.predict(inp, verbose=0)[0], -1).flatten()
    tp = np.sum((pred == 1) & (gt == 1))
    fp = np.sum((pred == 1) & (gt == 0))
    fn = np.sum((pred == 0) & (gt == 1))
    ious.append(tp / (tp + fp + fn + 1e-6))
    dices.append(2*tp / (2*tp + fp + fn + 1e-6))

print('=' * 47)
print('  VEIN DETECTION — VALIDATION SUMMARY')
print('=' * 47)
print(f'  Mean IoU  : {np.mean(ious):.4f}  +/- {np.std(ious):.4f}')
print(f'  Mean Dice : {np.mean(dices):.4f}  +/- {np.std(dices):.4f}')
print(f'  Median IoU: {np.median(ious):.4f}')
print(f'  IoU > 0.5 : {np.mean(np.array(ious) > 0.5)*100:.1f}% of frames')
print(f'  Checkpoint: {CKPT_PATH}')
print('=' * 47)
# Out:
# ===============================================
#   VEIN DETECTION — VALIDATION SUMMARY
# ===============================================
#   Mean IoU  : 0.9264  +/- 0.0750
#   Mean Dice : 0.9597  +/- 0.0542
#   Median IoU: 0.9414
#   IoU > 0.5 : 99.0% of frames
#   Checkpoint: /home/krish/vein_detection_task_3_training/output/vein/checkpoints/unet_resnet50_vein_best.keras
# ===============================================
